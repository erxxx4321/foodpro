# %%
import streamlit as st
import pandas as pd

df = pd.read_excel('食品營養成分資料庫2022版.xlsx', usecols='B, C, G, J, K, N, O, P, W')

df
# Out:
#             食品分類   樣品名稱  熱量(kcal)   粗蛋白(g)  粗脂肪(g)  總碳水化合物(g)  膳食纖維(g)  \
# 0            穀物類    大麥仁  364.6228   8.5578  1.5935    77.1418   8.4591
# 1            穀物類    大麥片  364.6155   8.6360  1.7900    76.6666   5.9987
# 2            穀物類   大麥仁粉  388.8475   7.1180  1.3142    84.9554   7.2048
# 3            穀物類     麥茶   17.7600      NaN     NaN     4.4400      NaN
# 4            穀物類     小米  370.1938  11.3135  3.6550    71.6907   2.2226
# ...          ...    ...       ...      ...     ...        ...      ...
# 2156  加工調理食品及其他類     啤酒   49.0056      NaN  0.0000     8.8764      NaN
# 2157  加工調理食品及其他類  陳年紹興酒  133.0776   1.8400  0.0000    19.0544      NaN
# 2158  加工調理食品及其他類   白葡萄酒   90.3096   0.1430  0.0000    14.1844      NaN
# 2159  加工調理食品及其他類   紅葡萄酒   92.5664   0.1030  0.0000    14.7886      NaN
# 2160  加工調理食品及其他類     雞精   34.1260   8.5810  0.0000     0.0000      NaN
#
#       糖質總量(g)    鈉(mg)
# 0       0.425  12.6115
# 1         NaN   7.1850
# 2       0.000   9.8300
# ...
